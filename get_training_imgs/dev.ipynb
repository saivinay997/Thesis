# %%
from imageResize import get_img_resize

input_source_dir = r'C:\SaiVinay\Thesis\Dataset\DIV2KRK_public\DIV2KRK\gt'
opt_kernel_path = r"C:\SaiVinay\Thesis\OTSR\git_code\OTSR\KernelGanResults\\results"

get_img_resize(input_source_dir, opt_kernel_path, cleanup_factor=8, upscale_factor=8)
# Out:
# Number of images in the source directory: 100
# Resizing images:   0%|          | 0/100 [00:00<?, ?it/s]
# input_img.size():  torch.Size([4, 1152, 2040])
# resize2_img.size():  torch.Size([4, 144, 255])
# resize2_cut_img.size():  torch.Size([4, 144, 248])
# skip kernel_path:C:\SaiVinay\Thesis\OTSR\git_code\OTSR\KernelGanResults\\results\img_100_gt\img_100_gt_kernel_x4.mat
# input_img.size():  torch.Size([4, 1536, 2040])
# resize2_img.size():  torch.Size([4, 192, 255])
# resize2_cut_img.size():  torch.Size([4, 192, 248])
# skip kernel_path:C:\SaiVinay\Thesis\OTSR\git_code\OTSR\KernelGanResults\\results\img_10_gt\img_10_gt_kernel_x4.mat
# input_img.size():  torch.Size([4, 1356, 2040])
# resize2_img.size():  torch.Size([4, 170, 255])
# resize2_cut_img.size():  torch.Size([4, 168, 248])
# skip kernel_path:C:\SaiVinay\Thesis\OTSR\git_code\OTSR\KernelGanResults\\results\img_11_gt\img_11_gt_kernel_x4.mat
# input_img.size():  torch.Size([4, 1536, 2040])
# ...

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 main()
#
# Input In [1], in main()
#       3 def main():
# ----> 4     get_img_resize()
#
# TypeError: get_img_resize() missing 6 required positional arguments: 'upscale_factor', 'cleanup_factor', 'source_files', 'tdsr_hr_dir', 'tdsr_lr_dir', and 'opt_kernel_path'
